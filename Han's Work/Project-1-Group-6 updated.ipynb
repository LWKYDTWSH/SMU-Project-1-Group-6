# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
file = "caffeine.csv"
df=pd.read_csv(file)
df
# Out:
#                            drink  Volume (ml)  Calories  Caffeine (mg)    type
# 0                   Costa Coffee   256.993715         0            277  Coffee
# 1    Coffee Friend Brewed Coffee   250.191810         0            145  Coffee
# 2             Hell Energy Coffee   250.191810       150            100  Coffee
# 3             Killer Coffee (AU)   250.191810         0            430  Coffee
# 4                   Nescafe Gold   250.191810         0             66  Coffee
# ..                           ...          ...       ...            ...     ...
# 605     Pep Talk Sparkling Water   354.882000         0             55   Water
# 606          Polar Seltzer Water   354.882000         0              0   Water
# 607       Yerbae Sparkling Water   354.882000         0            100   Water
# 608                  Tonic Water   295.735000       110              0   Water
# 609    MiO Energy Water Enhancer   236.588000         0             60   Water
#
# [610 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   drink          610 non-null    object
#  1   Volume (ml)    610 non-null    float64
#  2   Calories       610 non-null    int64
#  3   Caffeine (mg)  610 non-null    int64
#  4   type           610 non-null    object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 24.0+ KB

# %%
df.type.unique()
# Out:
# array(['Coffee', 'Energy Drinks', 'Energy Shots', 'Soft Drinks', 'Tea',
#        'Water'], dtype=object)

# %%
df.drink.unique()
# Out:
# array(['Costa Coffee', 'Coffee Friend Brewed Coffee',
#        'Hell Energy Coffee', 'Killer Coffee (AU)', 'Nescafe Gold',
#        'Espresso Monster', 'Dunkin Donuts Shot In The Dark',
#        'Illy Issimo Cafe', 'Starbucks Doubleshot Espresso',
#        'TrueStart Performance Coffee', 'Bizzy Cold Brew',
#        'Zola Coconut Water Espresso', 'Barista Bros Iced Coffee',
#        'Dare Iced Coffee', 'V Iced Coffee',
#        'Bottled Iced Coffee Dunkin Donuts',
#        'Starbucks Bottled Frappuccino', 'Stok Cold Brew',
#        'Wide Awake Iced Coffee Drinks', 'Caribou Canned Cold Brew',
#        'McDonalds Iced Coffee', 'Premier Protein Cafe Latte',
#        'Stumptown Cold Brew Coffee', 'Espresso Shot',
#        "Peet's Coffee Espresso", "Peet's Decaf Espresso",
#        'Gourmesso Coffee Pods', 'Nespresso Coffee Capsules',
#        'Stok Coffee Shots', 'Starbucks Bottled Iced Coffee',
#        'Baskin Robbins Cappuccino Blast', "Dunkin' Cold Brew",
#        "Dunkin' Donuts Iced Coffee", "Dunkin' Donuts Iced Latte",
#        'Dutch Bros Coffee (Classic)', 'Tim Hortons Large Brewed Coffee',
#        '7 Eleven Brewed Coffee', "Arby's Jamocha Shake",
#        'Biggby Brewed Coffee', 'Biggby Creamy Lattes',
#        'Biggby Iced Coffee', 'Caribou Brewed Coffee',
#        'Coffee Bean & Tea leaf Coffee', 'Einstein Bros Coffee', 'Latte',
#        'McDonalds (McCafe) Latte', 'McDonalds (McCafe) Mocha',
#        'McDonalds Coffee', 'Panera Bread Coffee', "Peet's Brewed Coffee",
#        "Peet's Caffe Americano", "Peet's Caffe Latte",
#        "Peet's Caffe Mocha", "Peet's Cappuccino", "Peet's Iced Coffee",
#        "Peet's Iced Latte", "Peet's Iced Mocha",
#        'Starbucks Caramel Macchiato', 'Starbucks Cold Brew Coffee',
#        'Starbucks Decaf Coffee', 'Starbucks Grande Caffe Americano',
#        'Starbucks Grande Caffe Latte', 'Starbucks Grande Caffe Mocha',
#        'Starbucks Grande Cappuccino', 'Starbucks Grande Coffee',
#        'Starbucks Iced Americano', 'Starbucks Nitro Cold Brew Coffee',
#        'Starbucks Pink Drink', 'Starbucks Pumpkin Cream Cold Brew',
#        'Starbucks Refreshers', 'Wawa Coffee',
#        'Private Selection Canned Espresso', 'Starbucks Doubleshot Energy',
#        'Wide Awak Energy Coffee', 'Chick-fil-A Frosted Coffee',
#        'Chick-fil-A Iced Coffee', "Dunkin' Donuts Brewed Coffee",
#        "Dunkin' Donuts Dunkaccino", "Dunkin' Donuts Extra Charged Coffee",
#        "Dunkin' Donuts Latte", 'Americano Coffee',
#        'Big Train Java Chip Ice Coffee', 'Biohazard Coffee',
#        'Black Ink Coffee', 'Black Insomnia Coffee',
#        'Black Label Brewed Coffee', 'Cafe Bustelo', 'Caffe Mocha',
#        'Caffe Nero Coffee', 'Cannonball Coffee Maximum Charge (UK)',
#        'Cappuccino', 'Death Wish Coffee',
#        'Devils Brew Extreme Caffeine Coffee', 'Flat White',
#        'GymBrew Coffee', 'High Voltage Coffee (AU)',
#        'International Delight Iced Coffee',
#        "Seattle's Best Brewed Coffee", 'Starbucks Iced Espresso Classics',
#        'Stipe Miocic Extra Strength Coffee', 'Sudden Instant Coffee',
#        'Taft Coffee (EU)', 'Very Strong Coffee',
#        'Chameleon Cold Brew With Milk', 'Muscle Milk Coffee House',
#        'SlimFast Shake - Cappuccino', 'Starbucks Bottled Cold Brew',
#        'Starbucks Canned Nitro Cold Brew', 'Starbucks Cold & Crafted',
#        'Stumptown Nitro Cold Brew', 'Sunup Pure Green Coffee',
#        'Wide Awake Coffee Cold Brew', 'Chameleon Cold Brew RTD',
#        'Chick-fil-A Brewed Coffee', 'CoolBrew Coffee',
#        'Tim Hortons Small French Vanilla Coffee', 'La Colombe Cold Brew',
#        'La Colombe Draft Latte', 'Alpine Start Instant Coffee',
#        'Bulletproof Coffee', 'Califia Farms Cold Brew Coffee',
#        'CBD Coffee', 'Chameleon Cold Brew Coffee', 'Coffee',
#        'Coffee (Decaf, Instant)', 'Coffee (Instant)', 'Coffee Leaf Tea',
#        'Crio Bru Brewed Cacao', 'Death Wish Canned Cold Brew',
#        'Death Wish Latte', 'Decaf Coffee', 'Driftaway Coffee',
#        "Eight O'Clock Coffee", 'Folgers Coffee', 'Gold Peak Coffee',
#        'Gothrider Gasoline Coffee', 'High Brew Coffee',
#        'Indulgio Cappuccino', 'K Cup Decaf', 'K-Cup Coffee',
#        'Maxwell House Coffee', 'Maxwell House Max Boost Coffee',
#        'Nescafe Dolce Gusto', 'Nescafe Ice Java', 'Nescafe Ricoffy',
#        'Nestle Milo', 'Noocaf Smart Coffee', 'Ocean Spray Brew',
#        'Purity Coffee', 'Revv Coffee Pods', 'Robusta Coffee',
#        'Starbucks 2X Coffee Pods', 'Starbucks Cordusio Mocha',
#        'Starbucks Verismo Coffee Pods', 'Starbucks Via Ready Brew',
#        'Steep 18 Cold Brew', "Taster's Choice Instant Coffee",
#        'Voila Instant Coffee', 'Waka Decaf Instant Coffee',
#        'Waka Indian Instant Coffee', 'Waka Instant Coffee',
#        'Whipped (Dalgona) Coffee', 'Mushroom Coffee', 'Cafe Con Leche',
#        'Choffy (roasted cacao)', 'COGO Caffeinated Hot Chocolate',
#        'Dripdash Kyoto Coffee', 'Long Black',
#        'Nescafe 3 in 1 Instant Coffee', "Gloria Jean's Coffee",
#        'Biggby Espresso', 'Greek Coffee (Metrios)', 'Turkish Coffee',
#        '28 Black Energy Drink', '4 Purpose Energy Drink',
#        'BEEBAD Energy Drink', 'Black Bruin Energy Drink',
#        'Blu Frog Energy Drink', 'Blue Bolt (UK)', 'Blue Charge (UK)',
#        'Blue Spark (UK)', 'Bomb Energy Drink', 'Boost Energy (UK)',
#        'Euro Shopper Energy Drink (EU)', 'Hell Energy Drink (EU)',
#        'Hype Energy Drink (EU)', 'M-150 Energy Drink',
#        'Pure Cofain 699 (EU)', 'Red Bull', 'Red Bull Editions',
#        'Red Bull Sugarfree', 'Red Bull Zero', 'Scheckters Energy Drink',
#        'Slammers Energy Drink (EU)', 'Source 1899 (UK)',
#        'Taurus Energy Drink', 'TENZING Natural Energy',
#        'Tiger Energy Drink', 'Tweaker Energy Drink',
#        'Virtue Clean Energy Beverage', 'Wildcat Energy Drink (UK)',
#        'X Ray Energy Drink', 'OK Energy Drink',
#        'Power Horse Energy Drink (EU)', 'V Energy Drink',
#        'XL Energy Drink (EU)', 'Crave Energy Drink (UK)', 'Bomba (EU)',
#        'Cintron Energy Drink', 'Dutch Bros Blue Rebel Energy Drink',
#        'XS Energy Drink', 'Wild Tiger Energy Drink',
#        'Liquid Ice Energy Drink', 'Rush! Energy Drink', 'Monster Hydro',
#        'Monster Import', 'Moose Juice Energy Drink', 'Club Mate (EU)',
#        'Demon Energy Drink', 'LevlUp Gaming Booster',
#        'Monster Ripper Energy Juice (UK)', 'Monster The Doctor VR46 (UK)',
#        'Mother Energy Drink', 'Protein2O + Energy',
#        'Strike Force Energy Drink Mix', '4C Energy Drink Mix',
#        'Arizona Arnold Palmer Half and Half', 'Gatorade Bolt 24 Energize',
#        'Live+ Energy Drink', 'Pure Kick Energy Drink Mix',
#        'Monster Dragon Tea', 'Monster Rehab', 'Neuro Sonic', 'Lucozade',
#        'Fakeer Energy Drink (EU)', 'Arizona Energy Drink Rx', 'Bai Boost',
#        'NOCCO Energy Drink (EU)', 'Carabao Energy Drink (UK)',
#        'Irn Bru (UK)', 'Soylent Stacked', 'Red Eye Energy Drink',
#        'Mega Monster Energy Drink', 'Amino Force Energy Drink',
#        'Bodyarmour Edge', 'SoBe Energy Citrus', 'ABB Turbo Tea Zero',
#        'Bai Antioxidant Infusion', 'Viso Energy Drink', '3D Energy Drink',
#        'Adrenaline Shoc', 'Alsa Energy Drink Mix', 'Bang Energy',
#        'Bang Keto Coffee', 'Bang Natural', 'Bang Sweet Tea',
#        'Beaver Buzz Energy Drink', 'Berzerk Energy Drink Mix',
#        'C4 Energy Drink', 'C4 Smart Energy Drink',
#        'C4 Ultimate Energy Drink', 'Celsius Heat Energy Drink',
#        'Crunk Energy Drink', 'Crystal Light Energy Mix',
#        'Electric Monkey Wild Energy Drink', 'Full Throttle Energy Drink',
#        'GFuel Cans', 'GFuel Energy Drink Mix', 'Go Fast Energy Drink',
#        'Go Fast High Octane Energy Drink', 'Great Value Energy Drink Mix',
#        'Gridlock Energy Drink', 'Hi Ball Energy Drink',
#        'Joker Mad Energy', 'Liquid Help Energy Drink',
#        'Loud Energy Drink', 'Monster Assault', 'Monster Energy',
#        'Monster Juice', 'Monster Lo-Carb', 'Monster Mango Loco',
#        'Monster Mule', 'Monster Pipeline Punch', 'Monster Ultra',
#        'Monster Zero Sugar', 'Mountain Dew Amp', 'Mountain Dew Game Fuel',
#        'Mountain Dew Rise', 'NOS Energy Drink', 'Nuun Sport',
#        'Propel Zero Powder', 'Pure Boost Energy Drink Mix',
#        'Quake Energy Berry Blast Slurpee', 'Quake Energy Drink',
#        'Raze Energy Drink', 'Reign Total Body Fuel',
#        'Rip It Energy Drink', 'Rockstar Boom',
#        'Rockstar Energy Drink (Original)', 'Rockstar Halo Infinite',
#        'Rockstar Juiced', 'Rockstar Punched', 'Rockstar Pure Zero',
#        'Rockstar Recovery', 'Rockstar Sugar Free', 'Rockstar Thermo',
#        'Rockstar XDurance', 'Rockstar Zero Carb',
#        'Rogue Energy Drink Mix', 'Rowdy Energy Drink',
#        'Sneak Energy Drink Mix', 'Solimo Energy Drink',
#        'Speed Energy Fuel', 'Spider Energy Drink',
#        'Spike Hardcore Energy', 'Triton Energy Drink',
#        'True Lemon Energy Mix', 'Ugly Energy Water', 'Venom Death Adder',
#        'Wired X 3000 Energy Drink', 'Wired X Berry Rush',
#        'Wired X344 Energy Drink', 'Xyience Energy Drink',
#        'ZipFizz Energy Drink Mix', 'Zoa Energy Drink', 'Java Monster',
#        'Java Monster 300', 'Muscle Monster',
#        'Rockstar Organic Energy Drink', 'Starbucks Triple Shot Energy',
#        'Alani Nu Energy Drink', 'ALL IN Energy Drink',
#        'AXIO Energy Drink Mix', 'Bing Energy Drink', 'BreinFuel',
#        'Burn Energy Drink', 'C4 On The Go', 'Celsius Energy Drink',
#        'Celsius Stevia', 'Coca-Cola Cherry Vanilla', 'Coca-Cola Energy',
#        'Cocaine Energy Drink', 'Dark Dog Organic Energy',
#        'Duff Energy Drink', 'EBOOST Super Fuel', 'EnerBee Energy Drink',
#        'Go Girl Energy Drink', 'GURU Energy Drink', 'Hyde Xtreme',
#        'Java Kick Coffee Cola', 'Kill Cliff Energy X Recover',
#        'Kill Cliff Ignite', 'Kona Gold Energy Drink',
#        'Marquis Energy Drink', 'MATI Energy Drink',
#        'Meltdown Ketone Drink', 'Monster Maxx', 'Nerd Focus',
#        'Octane Energy Drink Mix', 'Red Power Elixir',
#        'Red Thunder Energy Drink',
#        'RootJack Caffeinated Pirate Root Beer', 'Runa',
#        'Sambazon Amazon Energy Drink', 'Spike Shooter', 'Steaz Energy',
#        'T-Virus Antidote', 'Tru Energy Wakeup', 'UPTIME Energy Drink',
#        'USANA Rev3 Energy Drink', 'Xtreme Shock Energy Drink',
#        'Zest Sparkling Tea', 'Zevia Energy Drink', 'Cran Energy Juice',
#        'Mamma Chia Energy', 'Oikos Pro Fuel', 'Advocare Slim',
#        'Arbonne Energy Fizz Stck', 'Berocca',
#        'Best Choice Strawberry Energy Drink Mix',
#        'EBOOST Energy Drink Mix', 'EBOOST Workout Crusher Mix',
#        'Great Value Energy Drink Enhancers', 'Kin Spritz',
#        'LYFT Energy Mix', 'PerformElite Pre-Workout',
#        'Perk Energy Beverage', 'Redline Princess',
#        'Redline Xtreme Energy Drink', 'Roaring Lion Energy Drink',
#        'Spark Energy Drink Mix', 'V8 +Energy Drink',
#        'Spike Energy Double Shot', 'Zombie Blood Energy Potion',
#        'Proper Wild Energy Shot', 'Redline Max 300', '5 Hour Energy',
#        '5 Hour Energy Extra Strength', 'E6 Energy Shot',
#        'Eternal Energy Extra Strength', 'Eternal Energy Shot',
#        'Woke Up Energy Shot', 'Equip Pure Energy Shot',
#        'Mana Energy Potion', 'Clif Shot Energy Gel',
#        'Screamin Energy Max Hit', 'Vital 4U Liquid Energy',
#        'Kaffn8 Liquified Caffeine', 'Bang Shot', 'Redline Xtreme Shot',
#        '7-Eleven Energy Shot', 'Advocare Slam Energy Shot',
#        'Balance Active Shot', 'Balance Energy Shot',
#        'Forto Organic Coffee Shot', 'Kirkland Energy Shot',
#        'Neu Nootropic Shot', 'Nutramint Smart Serum',
#        'Performance Caffeine', 'Phoenix Energy Shot',
#        'Red Thunder Energy Shot', 'Red Thunder Extra Strength',
#        "Reed's Ginger Energize Shot", 'Rip It Energy Shot',
#        'Stacker Extreme Energy Shot', 'Tweaker Shot', 'TruBrain Extra',
#        'X-Mode Energy Shot', 'Red Bull Simply Cola', 'Afri Cola',
#        'Fritz Kola (EU)', 'Pepsi Max (UK)', 'Premium Cola (EU)',
#        'Tropicana Twister Soda', 'Bawls', 'Mountain Dew Kickstart',
#        'Sprecher Cherry Cola', '7-Up', 'A&W Cream Soda', 'A&W Root Beer',
#        'A&W Zero Sugar Cream Soda', 'Ale 8 1', 'Barqs Red Creme Soda',
#        'Barqs Root Beer', 'Big Red Soda',
#        'Canada Dry Green Tea Ginger Ale', 'Cheerwine',
#        'Coca-Cola Caffeine Free', 'Coca-Cola Cherry',
#        'Coca-Cola Cherry Zero Sugar', 'Coca-Cola Classic',
#        'Coca-Cola Orange Vanilla', 'Coca-Cola Vanilla',
#        'Coca-Cola Vanilla Zero Sugar', 'Coca-Cola With Coffee',
#        'Coca-Cola Zero Sugar', 'Diet Barqs Root Beer', 'Diet Cheerwine',
#        'Diet Coke', 'Diet Coke with Splenda', 'Diet Dr Pepper',
#        'Diet Mountain Dew', 'Diet Pepsi', 'Diet RC Cola',
#        'Diet Wild Cherry Pepsi', 'doc Soda', 'Double Cola', 'Dr Pepper',
#        'Dr Pepper 10', 'Dr Shasta Soda', 'Fanta', 'Faygo Cola',
#        'Faygo Moon Mist', 'Fresca', 'Ginger Ale', 'Green Cola',
#        'IBC Root Beer', 'Inca Kola',
#        'Kickapoo Soda: Joy Juice & Fruit Shine', 'Mello Yello',
#        'Mountain Dew', 'Mountain Dew Baja Blast', 'Mountain Dew Code Red',
#        'Mountain Dew Live Wire', 'Mountain Dew Major Melon',
#        'Mountain Dew Voltage', 'Mountain Dew Zero Sugar', 'Moxie Soda',
#        'Mug Root Beer', 'Orange Crush', 'PC Cola', 'PC Cola Diet',
#        'Pepsi', 'Pepsi Caffeine Free', 'Pepsi Made With Sugar',
#        'Pepsi Zero Sugar', 'Pibb Xtra', 'RC (Royal Crown) Cola',
#        'Ritz Cola', 'Ruby Red Squirt', 'Sarsaparilla', 'Shasta Cola',
#        'Shasta Diet Cola', 'Shasta Mountain Rush', 'Ski Soda', 'Slurpee',
#        'Sprite', 'Squirt Soda', 'Starbucks Refreshers Canned',
#        'Sun Drop Soda', 'Sunkist Orange Soda', 'Vernors Ginger Ale',
#        'Wave Soda', 'Wild Cherry Pepsi', 'Zevia Cola',
#        'Boost Nutritional Drink', 'Mucho Mango Energy Drink',
#        'Soda Stream', 'PG Tips Black Tea', 'Sencha Green Tea Shot',
#        'Xingtea Iced Green Tea', 'Gold Peak Tea', 'Pure Leaf Iced Tea',
#        'Honest Iced Tea', 'Nestea Iced Tea', 'Oi Ocha Green Tea',
#        "Teas' Tea Oolong", 'Guayaki Canned Yerba Mate',
#        "Inko's White Tea Energy", 'Master Brew Kombucha',
#        'McDonalds Sweet Tea', "Dunkin' Donuts Iced Tea", 'Fuze Iced Tea',
#        'Peace Tea', 'Lipton Iced Tea', 'SoBe Green Tea',
#        'Arizona Iced Tea', 'Biggby Iced Tea', 'Chick-fil-A Iced Tea',
#        'Guayaki Yerba Mate Bottled Tea', 'Snapple Tea',
#        'Southern Sweet Tea', 'Taiwanese Milk Tea', "Wendy's Iced Tea",
#        'Xing Craft Brew', 'Brew Dr Kombucha Uplift', 'Brisk Iced Tea',
#        'KOE Kombucha', 'Tejava Iced Tea', 'Turkey Hill Iced Tea',
#        'Big Train Spiced Chai', 'Bigelow Tea', 'Brown Rice Tea',
#        'Chai Tea', 'Cold Brew Tea', 'Crystal Light Iced Tea',
#        'Fast Lane Black Tea', 'Guayusa Tea', 'HICAF Tea', 'K Cup Tea',
#        'Kombucha Tea', 'Lipton Natural Energy Tea', 'Lipton Tea',
#        'Matcha Tea', 'Morning Thunder Tea', 'Tazo Chai', 'Tea (Black)',
#        'Tea (Decaf)', 'Tea (Green)', 'Tea (Herbal)', 'Tea (Iced)',
#        'Tea (Instant)', 'Tea (Jasmine)', 'Tea (Oolong)', 'Tea (White)',
#        'Teavana Tea', 'Twig Tea (Kukicha)', 'Waka Instant Tea',
#        'Yellow Tea', 'Yerba Mate Tea', 'YMateina Yerba Mate',
#        'Zest Highly Caffeinated Tea', 'Oregon Chai Tea', 'Pacific Chai',
#        'Perrier Energize', '3 Water', 'Heroec Energy Water',
#        'Caribou BOUsted Sparkling Water', 'Phocus Sparkling Water',
#        'Poland Spring Sparkling Energy Water', 'Perrier Sparkling Water',
#        'VitaminWater Energy', 'VitaRain Zero Enhanced Water', 'Water Joe',
#        'Polar Frost Plus Energy', 'Hint Caffeine Kick Water',
#        'Sparkling Ice +Caffeine', 'AHA Sparkling Water',
#        'Arti Sparkling Water', "Bubbl'r Sparkling Water",
#        'Bubly Bounce Sparkling Water', 'Bubly Sparkling Water',
#        'GURU Sparkling Energy Water', 'La Croix Sparkling Water',
#        'Limitless Sparkling Water', 'Pep Talk Sparkling Water',
#        'Polar Seltzer Water', 'Yerbae Sparkling Water', 'Tonic Water',
#        'MiO Energy Water Enhancer'], dtype=object)

# %%
df.drink.sort_values().unique()
# Out:
# array(['28 Black Energy Drink', '3 Water', '3D Energy Drink',
#        '4 Purpose Energy Drink', '4C Energy Drink Mix', '5 Hour Energy',
#        '5 Hour Energy Extra Strength', '7 Eleven Brewed Coffee',
#        '7-Eleven Energy Shot', '7-Up', 'A&W Cream Soda', 'A&W Root Beer',
#        'A&W Zero Sugar Cream Soda', 'ABB Turbo Tea Zero',
#        'AHA Sparkling Water', 'ALL IN Energy Drink',
#        'AXIO Energy Drink Mix', 'Adrenaline Shoc',
#        'Advocare Slam Energy Shot', 'Advocare Slim', 'Afri Cola',
#        'Alani Nu Energy Drink', 'Ale 8 1', 'Alpine Start Instant Coffee',
#        'Alsa Energy Drink Mix', 'Americano Coffee',
#        'Amino Force Energy Drink', 'Arbonne Energy Fizz Stck',
#        "Arby's Jamocha Shake", 'Arizona Arnold Palmer Half and Half',
#        'Arizona Energy Drink Rx', 'Arizona Iced Tea',
#        'Arti Sparkling Water', 'BEEBAD Energy Drink',
#        'Bai Antioxidant Infusion', 'Bai Boost', 'Balance Active Shot',
#        'Balance Energy Shot', 'Bang Energy', 'Bang Keto Coffee',
#        'Bang Natural', 'Bang Shot', 'Bang Sweet Tea',
#        'Barista Bros Iced Coffee', 'Barqs Red Creme Soda',
#        'Barqs Root Beer', 'Baskin Robbins Cappuccino Blast', 'Bawls',
#        'Beaver Buzz Energy Drink', 'Berocca', 'Berzerk Energy Drink Mix',
#        'Best Choice Strawberry Energy Drink Mix', 'Big Red Soda',
#        'Big Train Java Chip Ice Coffee', 'Big Train Spiced Chai',
#        'Bigelow Tea', 'Biggby Brewed Coffee', 'Biggby Creamy Lattes',
#        'Biggby Espresso', 'Biggby Iced Coffee', 'Biggby Iced Tea',
#        'Bing Energy Drink', 'Biohazard Coffee', 'Bizzy Cold Brew',
#        'Black Bruin Energy Drink', 'Black Ink Coffee',
#        'Black Insomnia Coffee', 'Black Label Brewed Coffee',
#        'Blu Frog Energy Drink', 'Blue Bolt (UK)', 'Blue Charge (UK)',
#        'Blue Spark (UK)', 'Bodyarmour Edge', 'Bomb Energy Drink',
#        'Bomba (EU)', 'Boost Energy (UK)', 'Boost Nutritional Drink',
#        'Bottled Iced Coffee Dunkin Donuts', 'BreinFuel',
#        'Brew Dr Kombucha Uplift', 'Brisk Iced Tea', 'Brown Rice Tea',
#        "Bubbl'r Sparkling Water", 'Bubly Bounce Sparkling Water',
#        'Bubly Sparkling Water', 'Bulletproof Coffee', 'Burn Energy Drink',
#        'C4 Energy Drink', 'C4 On The Go', 'C4 Smart Energy Drink',
#        'C4 Ultimate Energy Drink', 'CBD Coffee',
#        'COGO Caffeinated Hot Chocolate', 'Cafe Bustelo', 'Cafe Con Leche',
#        'Caffe Mocha', 'Caffe Nero Coffee',
#        'Califia Farms Cold Brew Coffee',
#        'Canada Dry Green Tea Ginger Ale',
#        'Cannonball Coffee Maximum Charge (UK)', 'Cappuccino',
#        'Carabao Energy Drink (UK)', 'Caribou BOUsted Sparkling Water',
#        'Caribou Brewed Coffee', 'Caribou Canned Cold Brew',
#        'Celsius Energy Drink', 'Celsius Heat Energy Drink',
#        'Celsius Stevia', 'Chai Tea', 'Chameleon Cold Brew Coffee',
#        'Chameleon Cold Brew RTD', 'Chameleon Cold Brew With Milk',
#        'Cheerwine', 'Chick-fil-A Brewed Coffee',
#        'Chick-fil-A Frosted Coffee', 'Chick-fil-A Iced Coffee',
#        'Chick-fil-A Iced Tea', 'Choffy (roasted cacao)',
#        'Cintron Energy Drink', 'Clif Shot Energy Gel', 'Club Mate (EU)',
#        'Coca-Cola Caffeine Free', 'Coca-Cola Cherry',
#        'Coca-Cola Cherry Vanilla', 'Coca-Cola Cherry Zero Sugar',
#        'Coca-Cola Classic', 'Coca-Cola Energy',
#        'Coca-Cola Orange Vanilla', 'Coca-Cola Vanilla',
#        'Coca-Cola Vanilla Zero Sugar', 'Coca-Cola With Coffee',
#        'Coca-Cola Zero Sugar', 'Cocaine Energy Drink', 'Coffee',
#        'Coffee (Decaf, Instant)', 'Coffee (Instant)',
#        'Coffee Bean & Tea leaf Coffee', 'Coffee Friend Brewed Coffee',
#        'Coffee Leaf Tea', 'Cold Brew Tea', 'CoolBrew Coffee',
#        'Costa Coffee', 'Cran Energy Juice', 'Crave Energy Drink (UK)',
#        'Crio Bru Brewed Cacao', 'Crunk Energy Drink',
#        'Crystal Light Energy Mix', 'Crystal Light Iced Tea',
#        'Dare Iced Coffee', 'Dark Dog Organic Energy',
#        'Death Wish Canned Cold Brew', 'Death Wish Coffee',
#        'Death Wish Latte', 'Decaf Coffee', 'Demon Energy Drink',
#        'Devils Brew Extreme Caffeine Coffee', 'Diet Barqs Root Beer',
#        'Diet Cheerwine', 'Diet Coke', 'Diet Coke with Splenda',
#        'Diet Dr Pepper', 'Diet Mountain Dew', 'Diet Pepsi',
#        'Diet RC Cola', 'Diet Wild Cherry Pepsi', 'Double Cola',
#        'Dr Pepper', 'Dr Pepper 10', 'Dr Shasta Soda', 'Driftaway Coffee',
#        'Dripdash Kyoto Coffee', 'Duff Energy Drink',
#        'Dunkin Donuts Shot In The Dark', "Dunkin' Cold Brew",
#        "Dunkin' Donuts Brewed Coffee", "Dunkin' Donuts Dunkaccino",
#        "Dunkin' Donuts Extra Charged Coffee",
#        "Dunkin' Donuts Iced Coffee", "Dunkin' Donuts Iced Latte",
#        "Dunkin' Donuts Iced Tea", "Dunkin' Donuts Latte",
#        'Dutch Bros Blue Rebel Energy Drink',
#        'Dutch Bros Coffee (Classic)', 'E6 Energy Shot',
#        'EBOOST Energy Drink Mix', 'EBOOST Super Fuel',
#        'EBOOST Workout Crusher Mix', "Eight O'Clock Coffee",
#        'Einstein Bros Coffee', 'Electric Monkey Wild Energy Drink',
#        'EnerBee Energy Drink', 'Equip Pure Energy Shot',
#        'Espresso Monster', 'Espresso Shot',
#        'Eternal Energy Extra Strength', 'Eternal Energy Shot',
#        'Euro Shopper Energy Drink (EU)', 'Fakeer Energy Drink (EU)',
#        'Fanta', 'Fast Lane Black Tea', 'Faygo Cola', 'Faygo Moon Mist',
#        'Flat White', 'Folgers Coffee', 'Forto Organic Coffee Shot',
#        'Fresca', 'Fritz Kola (EU)', 'Full Throttle Energy Drink',
#        'Fuze Iced Tea', 'GFuel Cans', 'GFuel Energy Drink Mix',
#        'GURU Energy Drink', 'GURU Sparkling Energy Water',
#        'Gatorade Bolt 24 Energize', 'Ginger Ale', "Gloria Jean's Coffee",
#        'Go Fast Energy Drink', 'Go Fast High Octane Energy Drink',
#        'Go Girl Energy Drink', 'Gold Peak Coffee', 'Gold Peak Tea',
#        'Gothrider Gasoline Coffee', 'Gourmesso Coffee Pods',
#        'Great Value Energy Drink Enhancers',
#        'Great Value Energy Drink Mix', 'Greek Coffee (Metrios)',
#        'Green Cola', 'Gridlock Energy Drink', 'Guayaki Canned Yerba Mate',
#        'Guayaki Yerba Mate Bottled Tea', 'Guayusa Tea', 'GymBrew Coffee',
#        'HICAF Tea', 'Hell Energy Coffee', 'Hell Energy Drink (EU)',
#        'Heroec Energy Water', 'Hi Ball Energy Drink', 'High Brew Coffee',
#        'High Voltage Coffee (AU)', 'Hint Caffeine Kick Water',
#        'Honest Iced Tea', 'Hyde Xtreme', 'Hype Energy Drink (EU)',
#        'IBC Root Beer', 'Illy Issimo Cafe', 'Inca Kola',
#        'Indulgio Cappuccino', "Inko's White Tea Energy",
#        'International Delight Iced Coffee', 'Irn Bru (UK)',
#        'Java Kick Coffee Cola', 'Java Monster', 'Java Monster 300',
#        'Joker Mad Energy', 'K Cup Decaf', 'K Cup Tea', 'K-Cup Coffee',
#        'KOE Kombucha', 'Kaffn8 Liquified Caffeine',
#        'Kickapoo Soda: Joy Juice & Fruit Shine',
#        'Kill Cliff Energy X Recover', 'Kill Cliff Ignite',
#        'Killer Coffee (AU)', 'Kin Spritz', 'Kirkland Energy Shot',
#        'Kombucha Tea', 'Kona Gold Energy Drink', 'LYFT Energy Mix',
#        'La Colombe Cold Brew', 'La Colombe Draft Latte',
#        'La Croix Sparkling Water', 'Latte', 'LevlUp Gaming Booster',
#        'Limitless Sparkling Water', 'Lipton Iced Tea',
#        'Lipton Natural Energy Tea', 'Lipton Tea',
#        'Liquid Help Energy Drink', 'Liquid Ice Energy Drink',
#        'Live+ Energy Drink', 'Long Black', 'Loud Energy Drink',
#        'Lucozade', 'M-150 Energy Drink', 'MATI Energy Drink',
#        'Mamma Chia Energy', 'Mana Energy Potion', 'Marquis Energy Drink',
#        'Master Brew Kombucha', 'Matcha Tea', 'Maxwell House Coffee',
#        'Maxwell House Max Boost Coffee', 'McDonalds (McCafe) Latte',
#        'McDonalds (McCafe) Mocha', 'McDonalds Coffee',
#        'McDonalds Iced Coffee', 'McDonalds Sweet Tea',
#        'Mega Monster Energy Drink', 'Mello Yello',
#        'Meltdown Ketone Drink', 'MiO Energy Water Enhancer',
#        'Monster Assault', 'Monster Dragon Tea', 'Monster Energy',
#        'Monster Hydro', 'Monster Import', 'Monster Juice',
#        'Monster Lo-Carb', 'Monster Mango Loco', 'Monster Maxx',
#        'Monster Mule', 'Monster Pipeline Punch', 'Monster Rehab',
#        'Monster Ripper Energy Juice (UK)', 'Monster The Doctor VR46 (UK)',
#        'Monster Ultra', 'Monster Zero Sugar', 'Moose Juice Energy Drink',
#        'Morning Thunder Tea', 'Mother Energy Drink', 'Mountain Dew',
#        'Mountain Dew Amp', 'Mountain Dew Baja Blast',
#        'Mountain Dew Code Red', 'Mountain Dew Game Fuel',
#        'Mountain Dew Kickstart', 'Mountain Dew Live Wire',
#        'Mountain Dew Major Melon', 'Mountain Dew Rise',
#        'Mountain Dew Voltage', 'Mountain Dew Zero Sugar', 'Moxie Soda',
#        'Mucho Mango Energy Drink', 'Mug Root Beer',
#        'Muscle Milk Coffee House', 'Muscle Monster', 'Mushroom Coffee',
#        'NOCCO Energy Drink (EU)', 'NOS Energy Drink', 'Nerd Focus',
#        'Nescafe 3 in 1 Instant Coffee', 'Nescafe Dolce Gusto',
#        'Nescafe Gold', 'Nescafe Ice Java', 'Nescafe Ricoffy',
#        'Nespresso Coffee Capsules', 'Nestea Iced Tea', 'Nestle Milo',
#        'Neu Nootropic Shot', 'Neuro Sonic', 'Noocaf Smart Coffee',
#        'Nutramint Smart Serum', 'Nuun Sport', 'OK Energy Drink',
#        'Ocean Spray Brew', 'Octane Energy Drink Mix', 'Oi Ocha Green Tea',
#        'Oikos Pro Fuel', 'Orange Crush', 'Oregon Chai Tea', 'PC Cola',
#        'PC Cola Diet', 'PG Tips Black Tea', 'Pacific Chai',
#        'Panera Bread Coffee', 'Peace Tea', "Peet's Brewed Coffee",
#        "Peet's Caffe Americano", "Peet's Caffe Latte",
#        "Peet's Caffe Mocha", "Peet's Cappuccino",
#        "Peet's Coffee Espresso", "Peet's Decaf Espresso",
#        "Peet's Iced Coffee", "Peet's Iced Latte", "Peet's Iced Mocha",
#        'Pep Talk Sparkling Water', 'Pepsi', 'Pepsi Caffeine Free',
#        'Pepsi Made With Sugar', 'Pepsi Max (UK)', 'Pepsi Zero Sugar',
#        'PerformElite Pre-Workout', 'Performance Caffeine',
#        'Perk Energy Beverage', 'Perrier Energize',
#        'Perrier Sparkling Water', 'Phocus Sparkling Water',
#        'Phoenix Energy Shot', 'Pibb Xtra',
#        'Poland Spring Sparkling Energy Water', 'Polar Frost Plus Energy',
#        'Polar Seltzer Water', 'Power Horse Energy Drink (EU)',
#        'Premier Protein Cafe Latte', 'Premium Cola (EU)',
#        'Private Selection Canned Espresso', 'Propel Zero Powder',
#        'Proper Wild Energy Shot', 'Protein2O + Energy',
#        'Pure Boost Energy Drink Mix', 'Pure Cofain 699 (EU)',
#        'Pure Kick Energy Drink Mix', 'Pure Leaf Iced Tea',
#        'Purity Coffee', 'Quake Energy Berry Blast Slurpee',
#        'Quake Energy Drink', 'RC (Royal Crown) Cola', 'Raze Energy Drink',
#        'Red Bull', 'Red Bull Editions', 'Red Bull Simply Cola',
#        'Red Bull Sugarfree', 'Red Bull Zero', 'Red Eye Energy Drink',
#        'Red Power Elixir', 'Red Thunder Energy Drink',
#        'Red Thunder Energy Shot', 'Red Thunder Extra Strength',
#        'Redline Max 300', 'Redline Princess',
#        'Redline Xtreme Energy Drink', 'Redline Xtreme Shot',
#        "Reed's Ginger Energize Shot", 'Reign Total Body Fuel',
#        'Revv Coffee Pods', 'Rip It Energy Drink', 'Rip It Energy Shot',
#        'Ritz Cola', 'Roaring Lion Energy Drink', 'Robusta Coffee',
#        'Rockstar Boom', 'Rockstar Energy Drink (Original)',
#        'Rockstar Halo Infinite', 'Rockstar Juiced',
#        'Rockstar Organic Energy Drink', 'Rockstar Punched',
#        'Rockstar Pure Zero', 'Rockstar Recovery', 'Rockstar Sugar Free',
#        'Rockstar Thermo', 'Rockstar XDurance', 'Rockstar Zero Carb',
#        'Rogue Energy Drink Mix', 'RootJack Caffeinated Pirate Root Beer',
#        'Rowdy Energy Drink', 'Ruby Red Squirt', 'Runa',
#        'Rush! Energy Drink', 'Sambazon Amazon Energy Drink',
#        'Sarsaparilla', 'Scheckters Energy Drink',
#        'Screamin Energy Max Hit', "Seattle's Best Brewed Coffee",
#        'Sencha Green Tea Shot', 'Shasta Cola', 'Shasta Diet Cola',
#        'Shasta Mountain Rush', 'Ski Soda', 'Slammers Energy Drink (EU)',
#        'SlimFast Shake - Cappuccino', 'Slurpee', 'Snapple Tea',
#        'Sneak Energy Drink Mix', 'SoBe Energy Citrus', 'SoBe Green Tea',
#        'Soda Stream', 'Solimo Energy Drink', 'Source 1899 (UK)',
#        'Southern Sweet Tea', 'Soylent Stacked', 'Spark Energy Drink Mix',
#        'Sparkling Ice +Caffeine', 'Speed Energy Fuel',
#        'Spider Energy Drink', 'Spike Energy Double Shot',
#        'Spike Hardcore Energy', 'Spike Shooter', 'Sprecher Cherry Cola',
#        'Sprite', 'Squirt Soda', 'Stacker Extreme Energy Shot',
#        'Starbucks 2X Coffee Pods', 'Starbucks Bottled Cold Brew',
#        'Starbucks Bottled Frappuccino', 'Starbucks Bottled Iced Coffee',
#        'Starbucks Canned Nitro Cold Brew', 'Starbucks Caramel Macchiato',
#        'Starbucks Cold & Crafted', 'Starbucks Cold Brew Coffee',
#        'Starbucks Cordusio Mocha', 'Starbucks Decaf Coffee',
#        'Starbucks Doubleshot Energy', 'Starbucks Doubleshot Espresso',
#        'Starbucks Grande Caffe Americano', 'Starbucks Grande Caffe Latte',
#        'Starbucks Grande Caffe Mocha', 'Starbucks Grande Cappuccino',
#        'Starbucks Grande Coffee', 'Starbucks Iced Americano',
#        'Starbucks Iced Espresso Classics',
#        'Starbucks Nitro Cold Brew Coffee', 'Starbucks Pink Drink',
#        'Starbucks Pumpkin Cream Cold Brew', 'Starbucks Refreshers',
#        'Starbucks Refreshers Canned', 'Starbucks Triple Shot Energy',
#        'Starbucks Verismo Coffee Pods', 'Starbucks Via Ready Brew',
#        'Steaz Energy', 'Steep 18 Cold Brew',
#        'Stipe Miocic Extra Strength Coffee', 'Stok Coffee Shots',
#        'Stok Cold Brew', 'Strike Force Energy Drink Mix',
#        'Stumptown Cold Brew Coffee', 'Stumptown Nitro Cold Brew',
#        'Sudden Instant Coffee', 'Sun Drop Soda', 'Sunkist Orange Soda',
#        'Sunup Pure Green Coffee', 'T-Virus Antidote',
#        'TENZING Natural Energy', 'Taft Coffee (EU)', 'Taiwanese Milk Tea',
#        "Taster's Choice Instant Coffee", 'Taurus Energy Drink',
#        'Tazo Chai', 'Tea (Black)', 'Tea (Decaf)', 'Tea (Green)',
#        'Tea (Herbal)', 'Tea (Iced)', 'Tea (Instant)', 'Tea (Jasmine)',
#        'Tea (Oolong)', 'Tea (White)', "Teas' Tea Oolong", 'Teavana Tea',
#        'Tejava Iced Tea', 'Tiger Energy Drink',
#        'Tim Hortons Large Brewed Coffee',
#        'Tim Hortons Small French Vanilla Coffee', 'Tonic Water',
#        'Triton Energy Drink', 'Tropicana Twister Soda',
#        'Tru Energy Wakeup', 'TruBrain Extra', 'True Lemon Energy Mix',
#        'TrueStart Performance Coffee', 'Turkey Hill Iced Tea',
#        'Turkish Coffee', 'Tweaker Energy Drink', 'Tweaker Shot',
#        'Twig Tea (Kukicha)', 'UPTIME Energy Drink',
#        'USANA Rev3 Energy Drink', 'Ugly Energy Water', 'V Energy Drink',
#        'V Iced Coffee', 'V8 +Energy Drink', 'Venom Death Adder',
#        'Vernors Ginger Ale', 'Very Strong Coffee',
#        'Virtue Clean Energy Beverage', 'Viso Energy Drink',
#        'VitaRain Zero Enhanced Water', 'Vital 4U Liquid Energy',
#        'VitaminWater Energy', 'Voila Instant Coffee',
#        'Waka Decaf Instant Coffee', 'Waka Indian Instant Coffee',
#        'Waka Instant Coffee', 'Waka Instant Tea', 'Water Joe',
#        'Wave Soda', 'Wawa Coffee', "Wendy's Iced Tea",
#        'Whipped (Dalgona) Coffee', 'Wide Awak Energy Coffee',
#        'Wide Awake Coffee Cold Brew', 'Wide Awake Iced Coffee Drinks',
#        'Wild Cherry Pepsi', 'Wild Tiger Energy Drink',
#        'Wildcat Energy Drink (UK)', 'Wired X 3000 Energy Drink',
#        'Wired X Berry Rush', 'Wired X344 Energy Drink',
#        'Woke Up Energy Shot', 'X Ray Energy Drink', 'X-Mode Energy Shot',
#        'XL Energy Drink (EU)', 'XS Energy Drink', 'Xing Craft Brew',
#        'Xingtea Iced Green Tea', 'Xtreme Shock Energy Drink',
#        'Xyience Energy Drink', 'YMateina Yerba Mate', 'Yellow Tea',
#        'Yerba Mate Tea', 'Yerbae Sparkling Water',
#        'Zest Highly Caffeinated Tea', 'Zest Sparkling Tea', 'Zevia Cola',
#        'Zevia Energy Drink', 'ZipFizz Energy Drink Mix',
#        'Zoa Energy Drink', 'Zola Coconut Water Espresso',
#        'Zombie Blood Energy Potion', 'doc Soda'], dtype=object)

# %%
df.type.sort_values()
# Out:
# 0      Coffee
# 111    Coffee
# 112    Coffee
# 113    Coffee
# 114    Coffee
#         ...
# 585     Water
# 584     Water
# 608     Water
# 595     Water
# 609     Water
# Name: type, Length: 610, dtype: object

# %%
df.type.value_counts()
# Out:
# Energy Drinks    219
# Coffee           173
# Soft Drinks       90
# Tea               66
# Energy Shots      36
# Water             26
# Name: type, dtype: int64

# %%
df.drink.value_counts()
# Out:
# Costa Coffee                 1
# Redline Xtreme Shot          1
# Equip Pure Energy Shot       1
# Mana Energy Potion           1
# Clif Shot Energy Gel         1
#                             ..
# V Energy Drink               1
# XL Energy Drink (EU)         1
# Crave Energy Drink (UK)      1
# Bomba (EU)                   1
# MiO Energy Water Enhancer    1
# Name: drink, Length: 610, dtype: int64

# %%
grouped_df=df.groupby(["type"])
grouped_df.head(100)
# Out:
#                            drink  Volume (ml)  Calories  Caffeine (mg)    type
# 0                   Costa Coffee   256.993715         0            277  Coffee
# 1    Coffee Friend Brewed Coffee   250.191810         0            145  Coffee
# 2             Hell Energy Coffee   250.191810       150            100  Coffee
# 3             Killer Coffee (AU)   250.191810         0            430  Coffee
# 4                   Nescafe Gold   250.191810         0             66  Coffee
# ..                           ...          ...       ...            ...     ...
# 605     Pep Talk Sparkling Water   354.882000         0             55   Water
# 606          Polar Seltzer Water   354.882000         0              0   Water
# 607       Yerbae Sparkling Water   354.882000         0            100   Water
# 608                  Tonic Water   295.735000       110              0   Water
# 609    MiO Energy Water Enhancer   236.588000         0             60   Water
#
# [418 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['drink', 'Volume (ml)', 'Calories', 'Caffeine (mg)', 'type'], dtype='object')

# %%
df1=df.groupby("type")[['Volume (ml)','Calories','Caffeine (mg)']].mean().reset_index()
df1.head()
# Out:
#             type  Volume (ml)    Calories  Caffeine (mg)
# 0         Coffee   335.870855   73.497110     200.589595
# 1  Energy Drinks   388.971198   86.671233     147.867580
# 2   Energy Shots    57.742259   16.500000     193.416667
# 3    Soft Drinks   355.243454  111.111111      33.677778
# 4            Tea   360.474080   52.757576      55.863636

# %%
caffeine_per_100ml=df1["Caffeine (mg)"]/df1["Volume (ml)"]*100
caffeine_per_100ml
# Out:
# 0     59.722239
# 1     38.015046
# 2    334.965536
# 3      9.480197
# 4     15.497269
# 5     13.616857
# dtype: float64

# %%
calories_per_100ml=df1["Calories"]/df1["Volume (ml)"]*100
calories_per_100ml
# Out:
# 0    21.882551
# 1    22.282172
# 2    28.575259
# 3    31.277455
# 4    14.635609
# 5     2.924164
# dtype: float64

# %%
df1['caffeine_per_100ml']= df1["Caffeine (mg)"]/df1["Volume (ml)"]*100

# %%
df1
# Out:
#             type  Volume (ml)    Calories  Caffeine (mg)  caffeine_per_100ml  \
# 0         Coffee   335.870855   73.497110     200.589595           59.722239
# 1  Energy Drinks   388.971198   86.671233     147.867580           38.015046
# 2   Energy Shots    57.742259   16.500000     193.416667          334.965536
# 3    Soft Drinks   355.243454  111.111111      33.677778            9.480197
# 4            Tea   360.474080   52.757576      55.863636           15.497269
# 5          Water   394.590111   11.538462      53.730769           13.616857
#
#    calories_per_100ml
# 0           21.882551
# 1           22.282172
# 2           28.575259
# 3           31.277455
# 4           14.635609
# 5            2.924164

# %%
df1['calories_per_100ml']= df1["Calories"]/df1["Volume (ml)"]*100

# %%
df1.head()
# Out:
#             type  Volume (ml)    Calories  Caffeine (mg)  caffeine_per_100ml  \
# 0         Coffee   335.870855   73.497110     200.589595           59.722239
# 1  Energy Drinks   388.971198   86.671233     147.867580           38.015046
# 2   Energy Shots    57.742259   16.500000     193.416667          334.965536
# 3    Soft Drinks   355.243454  111.111111      33.677778            9.480197
# 4            Tea   360.474080   52.757576      55.863636           15.497269
#
#    calories_per_100ml
# 0           21.882551
# 1           22.282172
# 2           28.575259
# 3           31.277455
# 4           14.635609

# %%
df1.corr()
# Out:
#                Volume (ml)  Calories  Caffeine (mg)
# Volume (ml)       1.000000  0.447615      -0.554659
# Calories          0.447615  1.000000      -0.144163
# Caffeine (mg)    -0.554659 -0.144163       1.000000

# %%
# #caffeine vs type vs volume

# #Groupby type
# df_drink_type = df[['type','Volume (ml)','Calories','Caffeine (mg)']]
# drinks_type_groupby = df_drink_type.groupby(['type'])
# drinks_type = drinks_type_groupby['type'] 

# #caffeine
# drinks_caffeine = drinks_type_groupby['Caffeine (mg)'].mean()

# #volume
# drinks_volume =drinks_type_groupby['Volume (ml)'].mean()

# #calories
# drinks_calories =drinks_type_groupby['Calories'].mean()


# #create a DataFrame
# summary=pd.DataFrame({
#     "Caffeine":drinks_caffeine,
#     "Volume":drinks_volume,
#     "Calories":drinks_calories
# })

# summary
